# %% [markdown]
# #Linkedin Profile
#
# https://www.linkedin.com/in/johan-sebastian-sanchez-vargas-ab998920a

# %% [markdown]
# #Python For Data Science
# ![josanchezvacognitiveclassapplieddatasciencewithpython_PythonforDataScience.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #Data Analysis with Python![josanchezvacognitiveclassapplieddatasciencewithpython_DataAnalysiswithPython.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #Data Visualization with Python
# ![josanchezvacognitiveclassapplieddatasciencewithpython_DataVisualizationwithPython.JPG](data:image/jpeg;base64,...)
